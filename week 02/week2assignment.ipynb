# %%
# Week 2 Asssignment - Food Resources in California
### assignment for week 2, exploring data on food resources in California.

# %%
import pandas as pd
import geopandas as gpd

# %%
# importing pandas and geopandas library

# %%
pantries = gpd.read_file('Food_Resources_in_California_20240114-Copy1.csv')

# %%
# importing csv data from NDSC

# %%
type(pantries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
pantries.head()
# Out:
#                                      Name                Street Address  \
# 0  Agnes Memorial Church Of God In Christ  2372 International Boulevard
# 1      Alameda County Community Food Bank          7900 Edgewater Drive
# 2                      Salaam Food Pantry         4039 Irvington Avenue
# 3                            Sierra Winds           10354 Argonaut Lane
# 4                       St Patrick's Hall                  115 Court St
#
#       City State Zip Code   County         Phone  \
# 0  Oakland    CA    94601  Alameda  510-533-1101
# 1  Oakland    CA    94621  Alameda  510-635-3663
# 2  Fremont    CA    94538  Alameda  415-860-2409
# 3  Jackson    CA    95642   Amador
# 4  Jackson    CA    95642   Amador
#
#                                          Description Resource Type  \
# 0  Partners with the City of Oakland's Hunger Rel...   Food Pantry
# 1  Call our Helpline at: 1-800-870-FOOD (3663) or...     Food Bank
# ...

# %%
# showing first five entries in the dataset

# %%
pantries.info
# Out:
# <bound method DataFrame.info of                                                    Name  \
# 0                Agnes Memorial Church Of God In Christ
# 1                    Alameda County Community Food Bank
# 2                                    Salaam Food Pantry
# 3                                          Sierra Winds
# 4                                     St Patrick's Hall
# ...                                                 ...
# 1847  Central Valley Homeless Veterans Assistance Pr...
# 1848                               Foothill Food Pantry
# 1849                Freed Center For Independent Living
# 1850                                     Harmony Health
# 1851               Yuba Sutter Legal Center For Seniors
#
#                     Street Address        City State Zip Code   County  \
# 0     2372 International Boulevard     Oakland    CA    94601  Alameda
# 1             7900 Edgewater Drive     Oakland    CA    94621  Alameda
# ...

# %%
pantries.tail()
# Out:
#                                                    Name  \
# 1847  Central Valley Homeless Veterans Assistance Pr...
# 1848                               Foothill Food Pantry
# 1849                Freed Center For Independent Living
# 1850                                     Harmony Health
# 1851               Yuba Sutter Legal Center For Seniors
#
#                   Street Address        City State Zip Code County  \
# 1847                604 D Street  Marysville    CA    95901   Yuba
# 1848       10775 Texas Hill Road     Dobbins    CA    95935   Yuba
# 1849                508 J Street  Marysville    CA    95901   Yuba
# 1850  1908 N. Beale Road, Ste. E  Marysville    CA    95901   Yuba
# 1851                725 D Street  Marysville    CA    95901   Yuba
#
#                Phone                                        Description  \
# 1847  (530) 749-0907  To create a path away from homelessness and to...
# 1848  (530) 692-1250                                        Thurs 1-3pm
# ...

# %%
# shows last 5 entries in dataset

# %%
pantries.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
pantries.shape
# Out:
# (1852, 14)

# %%
# how many rows/columns

# %%
pantries.columns.to_list()
# Out:
# ['Name',
#  'Street Address',
#  'City',
#  'State',
#  'Zip Code',
#  'County',
#  'Phone',
#  'Description',
#  'Resource Type',
#  'Web Link',
#  'Notes',
#  'Latitude',
#  'Longitude',
#  'geometry']

# %%
# name of each column

# %%
pantries['Resource Type'].value_counts()
# Out:
# Resource Type
# Food Pantry                    1443
# Nutrition Services Program      108
# Food Distribution Program       106
# Food Bank                        73
# Emergency Food Assistance        72
# USDA Commodity Program           45
# Mobile Food Pantry                3
# Emergency Food Distribution       1
# Senior Food Box                   1
# Name: count, dtype: int64

# %%
# what types of food resources are included? and how many of each type are there?

# %%
pantries.loc[pantries['City'] == 'Los Angeles']
# Out:
#                                                   Name  \
# 329                    Aaron Community Cultural Center
# 332  Aids Project Los Angeles - Vance North Necessi...
# 334  Aids Project Los Angeles - Vance North Necessi...
# 335                       All Peoples Christian Center
# 338                           Angelica Lutheran Church
# ..                                                 ...
# 533          Washington Preparatory Senior High School
# 535  West Angeles Community Development Corporation...
# 537              West Washington L A Foursquare Church
# 539                          Wilson Senior High School
# 540                            World Harvest Food Bank
#
#                    Street Address         City State Zip Code       County  \
# 329           1010-B W. 108th St.  Los Angeles    CA    90044  Los Angeles
# 332           611 S. Kingsley Dr.  Los Angeles    CA    90005  Los Angeles
# 334             1807 E. 120th St.  Los Angeles    CA    90059  Los Angeles
# ...

# %%
# filtered to show only the resources in los angeles
